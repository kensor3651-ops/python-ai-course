# %% [markdown]
# **Мой первый расчёт**
# Какова итоговая стоимость 5 футболок по цене 800 рублей каждая со скидкой 15%?

# %%
5 * 800 * 0.85
# Out:
# 3400.0

# %% [markdown]
# Какова итоговая стоимость 15 шорт
# по цене 750 рублей каждая со скидкой 10%?

# %%
15 * 750 * 0.9
# Out:
# 10125.0

# %% [markdown]
# При покупке 5 футболок по 800 руб.
# со скидкой 15% итоговая стоимость
# составила 3400 руб.

# %% [markdown]
# При покупке 15 шорт по 750 руб.
# со скидкой 10% итоговая стоимость
# составила 10125 руб.
